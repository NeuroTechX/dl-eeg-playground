# %%
# Doesn't work. Google Colab has a Hard Drive Limit. 
#for i in range(1,25):
#  fname = "https://physionet.org/pn6/chbmit/chb{:02}".format(i)
#  !wget -r --no-parent {fname}

# !wget -r --no-parent "https://physionet.org/pn6/chbmit/chb01"
# Out:
# --2018-07-14 13:06:39--  https://physionet.org/pn6/chbmit/chb01
# Resolving physionet.org (physionet.org)... 128.30.30.88
# Connecting to physionet.org (physionet.org)|128.30.30.88|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://physionet.org/pn6/chbmit/chb01/ [following]
# --2018-07-14 13:06:39--  https://physionet.org/pn6/chbmit/chb01/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb01’
#
# physionet.org/pn6/c     [ <=>                ]   8.12K  --.-KB/s    in 0s
#
# 2018-07-14 13:06:39 (65.3 MB/s) - ‘physionet.org/pn6/chbmit/chb01’ saved [8320]
#
# Loading robots.txt; please ignore errors.
# --2018-07-14 13:06:39--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 106 [text/plain]
# ...

# %%
# !ls
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full',)).History will not be written to the database.
# datalab  physionet.org
