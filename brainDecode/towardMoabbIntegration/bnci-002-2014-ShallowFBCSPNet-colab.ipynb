# %% [markdown]
# First, download datasets (It will take a few minutes. You can comment out some of the files if you want a smaller dataset):

# %%
# reset to default base path
import os
os.chdir('/content/')

# if dl-eeg-playground already here, erase
# !rm -rf dl-eeg-playground

# clone dl-eeg-playground and cd to it
# !git clone https://github.com/NeuroTechX/dl-eeg-playground.git
os.chdir('dl-eeg-playground/brainDecode/towardMoabbIntegration')
# Out:
# Cloning into 'dl-eeg-playground'...
# remote: Counting objects: 113, done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 113 (delta 18), reused 34 (delta 6), pack-reused 62
# Receiving objects: 100% (113/113), 769.65 KiB | 2.30 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
#
# Download the whole BNCI 002-2014 dataset
#
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S01T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S01E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S02T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S02E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S03T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S03E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S04T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S04E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S05T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S05E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S06T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S06E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S07T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S07E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S08T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S08E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S09T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S09E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S10T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S10E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S11T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S11E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S12T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S12E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S13T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S13E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S14T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S14E.mat
# Out:
# --2018-05-19 01:31:40--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S01T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S01T.mat [following]
# --2018-05-19 01:31:40--  https://lampx.tugraz.at/~bci/database/002-2014/S01T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39794870 (38M)
# Saving to: ‘S01T.mat’
#
# S01T.mat            100%[===================>]  37.95M  24.0MB/s    in 1.6s
#
# 2018-05-19 01:31:42 (24.0 MB/s) - ‘S01T.mat’ saved [39794870/39794870]
#
# --2018-05-19 01:31:43--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S01E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S01E.mat [following]
# --2018-05-19 01:31:43--  https://lampx.tugraz.at/~bci/database/002-2014/S01E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23769588 (23M)
# Saving to: ‘S01E.mat’
#
# S01E.mat            100%[===================>]  22.67M  19.5MB/s    in 1.2s
#
# 2018-05-19 01:31:44 (19.5 MB/s) - ‘S01E.mat’ saved [23769588/23769588]
#
# --2018-05-19 01:31:46--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S02T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S02T.mat [following]
# --2018-05-19 01:31:46--  https://lampx.tugraz.at/~bci/database/002-2014/S02T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38364523 (37M)
# Saving to: ‘S02T.mat’
#
# S02T.mat            100%[===================>]  36.59M  23.8MB/s    in 1.5s
#
# 2018-05-19 01:31:47 (23.8 MB/s) - ‘S02T.mat’ saved [38364523/38364523]
#
# --2018-05-19 01:31:49--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S02E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S02E.mat [following]
# --2018-05-19 01:31:49--  https://lampx.tugraz.at/~bci/database/002-2014/S02E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22998442 (22M)
# Saving to: ‘S02E.mat’
#
# S02E.mat            100%[===================>]  21.93M  19.6MB/s    in 1.1s
#
# 2018-05-19 01:31:50 (19.6 MB/s) - ‘S02E.mat’ saved [22998442/22998442]
#
# --2018-05-19 01:31:51--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S03T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response...
# 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S03T.mat [following]
# --2018-05-19 01:31:51--  https://lampx.tugraz.at/~bci/database/002-2014/S03T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39739945 (38M)
# Saving to: ‘S03T.mat’
#
# S03T.mat            100%[===================>]  37.90M  23.0MB/s    in 1.6s
#
# 2018-05-19 01:31:53 (23.0 MB/s) - ‘S03T.mat’ saved [39739945/39739945]
#
# --2018-05-19 01:31:54--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S03E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S03E.mat [following]
# --2018-05-19 01:31:54--  https://lampx.tugraz.at/~bci/database/002-2014/S03E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23797275 (23M)
# Saving to: ‘S03E.mat’
#
# S03E.mat            100%[===================>]  22.69M  19.0MB/s    in 1.2s
#
# 2018-05-19 01:31:56 (19.0 MB/s) - ‘S03E.mat’ saved [23797275/23797275]
#
# --2018-05-19 01:31:57--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S04T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S04T.mat [following]
# --2018-05-19 01:31:57--  https://lampx.tugraz.at/~bci/database/002-2014/S04T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39607931 (38M)
# Saving to: ‘S04T.mat’
#
# S04T.mat            100%[===================>]  37.77M  23.8MB/s    in 1.6s
#
# 2018-05-19 01:31:59 (23.8 MB/s) - ‘S04T.mat’ saved [39607931/39607931]
#
# --2018-05-19 01:32:00--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S04E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S04E.mat [following]
# --2018-05-19 01:32:00--  https://lampx.tugraz.at/~bci/database/002-2014/S04E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23752764 (23M)
# Saving to: ‘S04E.mat’
#
# S04E.mat            100%[===================>]  22.65M  19.2MB/s    in 1.2s
#
# 2018-05-19 01:32:01 (19.2 MB/s) - ‘S04E.mat’ saved [23752764/23752764]
#
# --2018-05-19 01:32:02--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S05T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S05T.mat [following]
# --2018-05-19 01:32:03--  https://lampx.tugraz.at/~bci/database/002-2014/S05T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39091212 (37M)
# Saving to: ‘S05T.mat’
#
# S05T.mat              0%[                    ]       0  --.-KB/s
# S05T.mat            100%[===================>]  37.28M  22.5MB/s    in 1.7s
#
# 2018-05-19 01:32:04 (22.5 MB/s) - ‘S05T.mat’ saved [39091212/39091212]
#
# --2018-05-19 01:32:06--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S05E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S05E.mat [following]
# --2018-05-19 01:32:06--  https://lampx.tugraz.at/~bci/database/002-2014/S05E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23628634 (23M)
# Saving to: ‘S05E.mat’
#
# S05E.mat            100%[===================>]  22.53M  19.6MB/s    in 1.1s
#
# 2018-05-19 01:32:07 (19.6 MB/s) - ‘S05E.mat’ saved [23628634/23628634]
#
# --2018-05-19 01:32:08--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S06T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S06T.mat [following]
# --2018-05-19 01:32:08--  https://lampx.tugraz.at/~bci/database/002-2014/S06T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40027626 (38M)
# Saving to: ‘S06T.mat’
#
# S06T.mat            100%[===================>]  38.17M  23.1MB/s    in 1.7s
#
# 2018-05-19 01:32:10 (23.1 MB/s) - ‘S06T.mat’ saved [40027626/40027626]
#
# --2018-05-19 01:32:11--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S06E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S06E.mat [following]
# --2018-05-19 01:32:11--  https://lampx.tugraz.at/~bci/database/002-2014/S06E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23850651 (23M)
# Saving to: ‘S06E.mat’
#
# S06E.mat            100%[===================>]  22.75M  20.0MB/s    in 1.1s
#
# 2018-05-19 01:32:13 (20.0 MB/s) - ‘S06E.mat’ saved [23850651/23850651]
#
# --2018-05-19 01:32:14--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S07T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S07T.mat [following]
# --2018-05-19 01:32:14--  https://lampx.tugraz.at/~bci/database/002-2014/S07T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40261257 (38M)
# Saving to: ‘S07T.mat’
#
# S07T.mat             31%[=====>              ]  11.98M  9.52MB/s
# S07T.mat            100%[===================>]  38.40M  12.1MB/s    in 3.2s
#
# 2018-05-19 01:32:17 (12.1 MB/s) - ‘S07T.mat’ saved [40261257/40261257]
#
# --2018-05-19 01:32:19--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S07E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S07E.mat [following]
# --2018-05-19 01:32:19--  https://lampx.tugraz.at/~bci/database/002-2014/S07E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23997847 (23M)
# Saving to: ‘S07E.mat’
#
# S07E.mat            100%[===================>]  22.89M  20.0MB/s    in 1.1s
#
# 2018-05-19 01:32:20 (20.0 MB/s) - ‘S07E.mat’ saved [23997847/23997847]
#
# --2018-05-19 01:32:21--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S08T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S08T.mat [following]
# --2018-05-19 01:32:21--  https://lampx.tugraz.at/~bci/database/002-2014/S08T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39735612 (38M)
# Saving to: ‘S08T.mat’
#
# S08T.mat            100%[===================>]  37.89M  23.8MB/s    in 1.6s
#
# 2018-05-19 01:32:23 (23.8 MB/s) - ‘S08T.mat’ saved [39735612/39735612]
#
# --2018-05-19 01:32:24--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S08E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S08E.mat [following]
# --2018-05-19 01:32:24--  https://lampx.tugraz.at/~bci/database/002-2014/S08E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23791571 (23M)
# Saving to: ‘S08E.mat’
#
# S08E.mat            100%[===================>]  22.69M  19.3MB/s    in 1.2s
#
# 2018-05-19 01:32:26 (19.3 MB/s) - ‘S08E.mat’ saved [23791571/23791571]
#
# --2018-05-19 01:32:27--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S09T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S09T.mat [following]
# --2018-05-19 01:32:27--  https://lampx.tugraz.at/~bci/database/002-2014/S09T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39805150 (38M)
# Saving to: ‘S09T.mat’
#
# S09T.mat             67%[============>       ]  25.60M  21.2MB/s
# S09T.mat            100%[===================>]  37.96M  23.9MB/s    in 1.6s
#
# 2018-05-19 01:32:29 (23.9 MB/s) - ‘S09T.mat’ saved [39805150/39805150]
#
# --2018-05-19 01:32:30--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S09E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S09E.mat [following]
# --2018-05-19 01:32:30--  https://lampx.tugraz.at/~bci/database/002-2014/S09E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23610622 (23M)
# Saving to: ‘S09E.mat’
#
# S09E.mat            100%[===================>]  22.52M  20.7MB/s    in 1.1s
#
# 2018-05-19 01:32:31 (20.7 MB/s) - ‘S09E.mat’ saved [23610622/23610622]
#
# --2018-05-19 01:32:32--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S10T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S10T.mat [following]
# --2018-05-19 01:32:32--  https://lampx.tugraz.at/~bci/database/002-2014/S10T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39871971 (38M)
# Saving to: ‘S10T.mat’
#
# S10T.mat            100%[===================>]  38.02M  24.1MB/s    in 1.6s
#
# 2018-05-19 01:32:34 (24.1 MB/s) - ‘S10T.mat’ saved [39871971/39871971]
#
# --2018-05-19 01:32:35--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S10E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S10E.mat [following]
# --2018-05-19 01:32:35--  https://lampx.tugraz.at/~bci/database/002-2014/S10E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23750112 (23M)
# Saving to: ‘S10E.mat’
#
# S10E.mat            100%[===================>]  22.65M  19.0MB/s    in 1.2s
#
# 2018-05-19 01:32:37 (19.0 MB/s) - ‘S10E.mat’ saved [23750112/23750112]
#
# --2018-05-19 01:32:38--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S11T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S11T.mat [following]
# --2018-05-19 01:32:38--  https://lampx.tugraz.at/~bci/database/002-2014/S11T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40140184 (38M)
# Saving to: ‘S11T.mat’
#
# S11T.mat             58%[==========>         ]  22.33M  18.4MB/s
# S11T.mat            100%[===================>]  38.28M  22.4MB/s    in 1.7s
#
# 2018-05-19 01:32:40 (22.4 MB/s) - ‘S11T.mat’ saved [40140184/40140184]
#
# --2018-05-19 01:32:41--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S11E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S11E.mat [following]
# --2018-05-19 01:32:41--  https://lampx.tugraz.at/~bci/database/002-2014/S11E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24171700 (23M)
# Saving to: ‘S11E.mat’
#
# S11E.mat            100%[===================>]  23.05M  20.0MB/s    in 1.2s
#
# 2018-05-19 01:32:43 (20.0 MB/s) - ‘S11E.mat’ saved [24171700/24171700]
#
# --2018-05-19 01:32:44--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S12T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S12T.mat [following]
# --2018-05-19 01:32:44--  https://lampx.tugraz.at/~bci/database/002-2014/S12T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40093093 (38M)
# Saving to: ‘S12T.mat’
#
# S12T.mat            100%[===================>]  38.24M  22.8MB/s    in 1.7s
#
# 2018-05-19 01:32:46 (22.8 MB/s) - ‘S12T.mat’ saved [40093093/40093093]
#
# --2018-05-19 01:32:47--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S12E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S12E.mat [following]
# --2018-05-19 01:32:47--  https://lampx.tugraz.at/~bci/database/002-2014/S12E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23905075 (23M)
# Saving to: ‘S12E.mat’
#
# S12E.mat            100%[===================>]  22.80M  19.5MB/s    in 1.2s
#
# 2018-05-19 01:32:48 (19.5 MB/s) - ‘S12E.mat’ saved [23905075/23905075]
#
# --2018-05-19 01:32:49--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S13T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S13T.mat [following]
# --2018-05-19 01:32:50--  https://lampx.tugraz.at/~bci/database/002-2014/S13T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39819174 (38M)
# Saving to: ‘S13T.mat’
#
# S13T.mat             66%[============>       ]  25.21M  20.6MB/s
# S13T.mat            100%[===================>]  37.97M  23.6MB/s    in 1.6s
#
# 2018-05-19 01:32:51 (23.6 MB/s) - ‘S13T.mat’ saved [39819174/39819174]
#
# --2018-05-19 01:32:52--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S13E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S13E.mat [following]
# --2018-05-19 01:32:53--  https://lampx.tugraz.at/~bci/database/002-2014/S13E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23669359 (23M)
# Saving to: ‘S13E.mat’
#
# S13E.mat            100%[===================>]  22.57M  17.9MB/s    in 1.3s
#
# 2018-05-19 01:32:54 (17.9 MB/s) - ‘S13E.mat’ saved [23669359/23669359]
#
# --2018-05-19 01:32:55--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S14T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S14T.mat [following]
# --2018-05-19 01:32:55--  https://lampx.tugraz.at/~bci/database/002-2014/S14T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39859134 (38M)
# Saving to: ‘S14T.mat’
#
# S14T.mat            100%[===================>]  38.01M  23.7MB/s    in 1.6s
#
# 2018-05-19 01:32:57 (23.7 MB/s) - ‘S14T.mat’ saved [39859134/39859134]
#
# --2018-05-19 01:32:58--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S14E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S14E.mat [following]
# --2018-05-19 01:32:58--  https://lampx.tugraz.at/~bci/database/002-2014/S14E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23970887 (23M)
# Saving to: ‘S14E.mat’
#
# S14E.mat            100%[===================>]  22.86M  19.6MB/s    in 1.2s
#
# 2018-05-19 01:33:00 (19.6 MB/s) - ‘S14E.mat’ saved [23970887/23970887]

# %%
# move files into a dedicated folder
# !mkdir BBCIData
# !mv *.mat BBCIData

# %%
#install brain decode
# !pip install braindecode -q

# %%
# install pytorck
# ref: http://pytorch.org/
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.3.0.post4-{platform}-linux_x86_64.whl torchvision
import torch

# %% [markdown]
# Now, let's load data.
#
# We read the file for the desired subject, and parse the data to extract:
# - samplingRate
# - trialLength
# - X, a M x N x K matrix, which stands for trial x chan x samples
#     - the actual values are 160 x 15 x 2560
# - y, a M vector containing the labels {0,1}
#
# ref: Dataset description: https://lampx.tugraz.at/~bci/database/002-2014/description.pdf

# %%
import scipy.io as sio
import numpy as np
from os import listdir
from os.path import isfile, join

# prepare data containers
y = []
X = []

folder = "BBCIData"

for f in listdir(folder):
    # read file
    d1T = sio.loadmat(folder + "/" + f)
    
    samplingRate = d1T['data'][0][0][0][0][3][0][0]
    trialLength = 7*samplingRate

    # run through all training runs
    for run in range(len(d1T['data'][0])):
        y.append(d1T['data'][0][run][0][0][2][0]) # labels
        timestamps = d1T['data'][0][run][0][0][1][0] # timestamps
        rawData = d1T['data'][0][run][0][0][0].transpose() # chan x data

        # parse out data based on timestamps
        for start in timestamps:
            end = start + trialLength
            X.append(rawData[:,start:end]) #15 x 2560

    del rawData
    del d1T

# arrange data into num7py arrays
# also torch expect float32 for samples
# and int64 for labels {0,1}
X = np.array(X).astype(np.float32)
y = (np.array(y).flatten()-1).astype(np.int64)
print()
print(X.shape)
print(y.shape)


# rand permute dataset
idx = np.random.permutation(X.shape[0])

X = X[idx,:,:]
y = y[idx]
# Out:
# (2240, 15, 3584)
# (2240,)

# %%
# !ls

# load the globally trained network
from brainDecodeSKLearnWrapper.ShallowFBCSPNet_GeneralTrainer import ShallowFBCSPNet_GeneralTrainer

classifier = ShallowFBCSPNet_GeneralTrainer()
classifier.fit(X,y)
# Out:
# BBCIData  bnci-002-2014-ShallowFBCSPNet-colab.ipynb  brainDecodeSKLearnWrapper
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:67: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Epoch 0
# Train  Loss: 1.26560
# Train  Accuracy: 50.4%
# Test   Loss: 1.38466
# Test   Accuracy: 47.1%
# Epoch 1
# Train  Loss: 0.72924
# Train  Accuracy: 54.4%
# Test   Loss: 0.77198
# Test   Accuracy: 50.4%
# Epoch 2
# Train  Loss: 1.01843
# Train  Accuracy: 50.9%
# Test   Loss: 1.14158
# Test   Accuracy: 48.2%
# Epoch 3
# Train  Loss: 0.77743
# Train  Accuracy: 56.5%
# Test   Loss: 0.87395
# Test   Accuracy: 50.4%
# Epoch 4
# Train  Loss: 0.64853
# Train  Accuracy: 61.7%
# Test   Loss: 0.69623
# Test   Accuracy: 56.8%
# Epoch 5
# Train  Loss: 1.64574
# Train  Accuracy: 51.2%
# Test   Loss: 1.80096
# Test   Accuracy: 48.9%
# Epoch 6
# Train  Loss: 0.60164
# Train  Accuracy: 66.9%
# Test   Loss: 0.63895
# Test   Accuracy: 62.1%
# Epoch 7
# Train  Loss: 0.58024
