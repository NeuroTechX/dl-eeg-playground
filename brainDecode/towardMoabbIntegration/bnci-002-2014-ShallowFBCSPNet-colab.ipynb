# %% [markdown]
# # Two-Stages Deep Learning Project
#
# <p>This project has been developped by the Montreal Hacknight community. It derives from the braindecode framework and is aimed at being integrable into the Moabb project.</p>
#
# <p><ul>https://github.com/robintibor/braindecode</ul>
# <ul>https://github.com/NeuroTechX/moabb</ul></p>
#
# <p>This project wouldn't have been possible without the contribution of these people: Arna (...), Justin (...), Yannick Roy, Eamon Egan, (...) and it is currently being supported by Fred Simard (fs@re-ak.com)</p>

# %% [markdown]
# <p>This project consist in deriving a two-stages training process from the brain decode implementation of a Shallow Convolutional Network. The core motivation is to combine the strenghts of deep learning - that is being one of the most powerful ML algorithms out-there - while grinding down it's fall back - it requires an immense of data.</p>
#
# <p>The goal is to develop a method to train the network in two stages:</p>
# <p><ul>1) Train the network over a large dataset, this training forms some kind of prior over the network</ul>
# <ul>2) Train the network a second time, this time on the dataset of interest</ul>
# </p>
#
# <p>The premise motivating this approach is that the second training is likely to proceed faster than what is normally required to train a deep net, without sacrificing the performance; and, we suspect that the second training will be able to exploit the specificities of the dataset of interest in a way to surpasses the first training, which was trained on a generalistic dataset.</p>

# %%
"""
#
# Download the github, which contains the package with the networks
#
"""

# reset to default base path
import os
os.chdir('/content/')

# if dl-eeg-playground already here, erase
# !rm -rf dl-eeg-playground

# clone dl-eeg-playground and cd to it
# !git clone https://github.com/NeuroTechX/dl-eeg-playground.git
os.chdir('dl-eeg-playground/brainDecode/towardMoabbIntegration')
# Out:
# Cloning into 'dl-eeg-playground'...
# remote: Counting objects: 171, done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 171 (delta 26), reused 25 (delta 14), pack-reused 131
# Receiving objects: 100% (171/171), 1.25 MiB | 17.06 MiB/s, done.
# Resolving deltas: 100% (78/78), done.

# %%
#
# Download the whole BNCI 002-2014 dataset
#
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S01T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S01E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S02T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S02E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S03T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S03E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S04T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S04E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S05T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S05E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S06T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S06E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S07T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S07E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S08T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S08E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S09T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S09E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S10T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S10E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S11T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S11E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S12T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S12E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S13T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S13E.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S14T.mat
# !wget http://bnci-horizon-2020.eu/database/data-sets/002-2014/S14E.mat

# move files into a dedicated folder
# !mkdir BBCIData
# !mv *.mat BBCIData

#install brain decode
# !pip install braindecode -q

# install pytorch
# ref: http://pytorch.org/
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.3.0.post4-{platform}-linux_x86_64.whl torchvision
import torch

import scipy.io as sio
import numpy as np
from os import listdir
from os.path import isfile, join

# prepare data containers
y = []
X = []

"""
Now, let's load data.

We read the file for the desired subject, and parse the data to extract:
- samplingRate
- trialLength
- X, a M x N x K matrix, which stands for trial x chan x samples
    - the actual values are 160 x 15 x 2560
- y, a M vector containing the labels {0,1}

ref: Dataset description: https://lampx.tugraz.at/~bci/database/002-2014/description.pdf
"""

folder = "BBCIData"

for f in listdir(folder):
    # read file
    d1T = sio.loadmat(folder + "/" + f)
    
    samplingRate = d1T['data'][0][0][0][0][3][0][0]
    trialLength = 7*samplingRate

    # run through all training runs
    for run in range(len(d1T['data'][0])):
        y.append(d1T['data'][0][run][0][0][2][0]) # labels
        timestamps = d1T['data'][0][run][0][0][1][0] # timestamps
        rawData = d1T['data'][0][run][0][0][0].transpose() # chan x data

        # parse out data based on timestamps
        for start in timestamps:
            end = start + trialLength
            X.append(rawData[:,start:end]) #15 x 2560

    del rawData
    del d1T

# arrange data into num7py arrays
# also torch expect float32 for samples
# and int64 for labels {0,1}
X = np.array(X).astype(np.float32)
y = (np.array(y).flatten()-1).astype(np.int64)
print()
print(X.shape)
print(y.shape)


# rand permute dataset
idx = np.random.permutation(X.shape[0])

X = X[idx,:,:]
y = y[idx]
# Out:
# --2018-06-16 01:41:01--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S01T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S01T.mat [following]
# --2018-06-16 01:41:01--  https://lampx.tugraz.at/~bci/database/002-2014/S01T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39794870 (38M)
# Saving to: ‘S01T.mat’
#
# S01T.mat            100%[===================>]  37.95M  9.83MB/s    in 4.6s
#
# 2018-06-16 01:41:07 (8.32 MB/s) - ‘S01T.mat’ saved [39794870/39794870]
#
# --2018-06-16 01:41:08--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S01E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S01E.mat [following]
# --2018-06-16 01:41:08--  https://lampx.tugraz.at/~bci/database/002-2014/S01E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23769588 (23M)
# Saving to: ‘S01E.mat’
#
# S01E.mat            100%[===================>]  22.67M  6.11MB/s    in 3.7s
#
# 2018-06-16 01:41:12 (6.11 MB/s) - ‘S01E.mat’ saved [23769588/23769588]
#
# --2018-06-16 01:41:13--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S02T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S02T.mat [following]
# --2018-06-16 01:41:14--  https://lampx.tugraz.at/~bci/database/002-2014/S02T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38364523 (37M)
# Saving to: ‘S02T.mat’
#
# S02T.mat             24%[===>                ]   8.99M  2.90MB/s    eta 9s
# S02T.mat            100%[===================>]  36.59M  9.51MB/s    in 4.3s
#
# 2018-06-16 01:41:18 (8.48 MB/s) - ‘S02T.mat’ saved [38364523/38364523]
#
# --2018-06-16 01:41:20--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S02E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S02E.mat [following]
# --2018-06-16 01:41:20--  https://lampx.tugraz.at/~bci/database/002-2014/S02E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22998442 (22M)
# Saving to: ‘S02E.mat’
#
# S02E.mat            100%[===================>]  21.93M  5.83MB/s    in 3.8s
#
# 2018-06-16 01:41:24 (5.83 MB/s) - ‘S02E.mat’ saved [22998442/22998442]
#
# --2018-06-16 01:41:25--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S03T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S03T.mat [following]
# --2018-06-16 01:41:26--  https://lampx.tugraz.at/~bci/database/002-2014/S03T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39739945 (38M)
# Saving to: ‘S03T.mat’
#
# S03T.mat            100%[===================>]  37.90M  9.07MB/s    in 4.2s
#
# 2018-06-16 01:41:30 (9.07 MB/s) - ‘S03T.mat’ saved [39739945/39739945]
#
# --2018-06-16 01:41:31--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S03E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S03E.mat [following]
# --2018-06-16 01:41:32--  https://lampx.tugraz.at/~bci/database/002-2014/S03E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23797275 (23M)
# Saving to: ‘S03E.mat’
#
# S03E.mat              3%[                    ] 712.00K   427KB/s
# S03E.mat            100%[===================>]  22.69M  5.85MB/s    in 3.9s
#
# 2018-06-16 01:41:36 (5.85 MB/s) - ‘S03E.mat’ saved [23797275/23797275]
#
# --2018-06-16 01:41:37--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S04T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S04T.mat [following]
# --2018-06-16 01:41:37--  https://lampx.tugraz.at/~bci/database/002-2014/S04T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39607931 (38M)
# Saving to: ‘S04T.mat’
#
# S04T.mat            100%[===================>]  37.77M  9.51MB/s    in 4.2s
#
# 2018-06-16 01:41:42 (8.97 MB/s) - ‘S04T.mat’ saved [39607931/39607931]
#
# --2018-06-16 01:41:43--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S04E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S04E.mat [following]
# --2018-06-16 01:41:44--  https://lampx.tugraz.at/~bci/database/002-2014/S04E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23752764 (23M)
# Saving to: ‘S04E.mat’
#
# S04E.mat            100%[===================>]  22.65M  6.13MB/s    in 3.7s
#
# 2018-06-16 01:41:48 (6.13 MB/s) - ‘S04E.mat’ saved [23752764/23752764]
#
# --2018-06-16 01:41:49--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S05T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S05T.mat [following]
# --2018-06-16 01:41:49--  https://lampx.tugraz.at/~bci/database/002-2014/S05T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39091212 (37M)
# Saving to: ‘S05T.mat’
#
# S05T.mat              2%[                    ] 952.00K   492KB/s
# S05T.mat            100%[===================>]  37.28M  9.88MB/s    in 4.5s
#
# 2018-06-16 01:41:54 (8.31 MB/s) - ‘S05T.mat’ saved [39091212/39091212]
#
# --2018-06-16 01:41:55--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S05E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S05E.mat [following]
# --2018-06-16 01:41:56--  https://lampx.tugraz.at/~bci/database/002-2014/S05E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23628634 (23M)
# Saving to: ‘S05E.mat’
#
# S05E.mat            100%[===================>]  22.53M  6.33MB/s    in 3.6s
#
# 2018-06-16 01:42:00 (6.33 MB/s) - ‘S05E.mat’ saved [23628634/23628634]
#
# --2018-06-16 01:42:01--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S06T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S06T.mat [following]
# --2018-06-16 01:42:01--  https://lampx.tugraz.at/~bci/database/002-2014/S06T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40027626 (38M)
# Saving to: ‘S06T.mat’
#
# S06T.mat            100%[===================>]  38.17M  9.75MB/s    in 4.4s
#
# 2018-06-16 01:42:06 (8.69 MB/s) - ‘S06T.mat’ saved [40027626/40027626]
#
# --2018-06-16 01:42:07--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S06E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S06E.mat [following]
# --2018-06-16 01:42:08--  https://lampx.tugraz.at/~bci/database/002-2014/S06E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23850651 (23M)
# Saving to: ‘S06E.mat’
#
# S06E.mat              4%[                    ] 952.00K   492KB/s
# S06E.mat            100%[===================>]  22.75M  5.93MB/s    in 3.8s
#
# 2018-06-16 01:42:12 (5.93 MB/s) - ‘S06E.mat’ saved [23850651/23850651]
#
# --2018-06-16 01:42:13--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S07T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S07T.mat [following]
# --2018-06-16 01:42:13--  https://lampx.tugraz.at/~bci/database/002-2014/S07T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40261257 (38M)
# Saving to: ‘S07T.mat’
#
# S07T.mat            100%[===================>]  38.40M  9.74MB/s    in 4.4s
#
# 2018-06-16 01:42:18 (8.70 MB/s) - ‘S07T.mat’ saved [40261257/40261257]
#
# --2018-06-16 01:42:19--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S07E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S07E.mat [following]
# --2018-06-16 01:42:20--  https://lampx.tugraz.at/~bci/database/002-2014/S07E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23997847 (23M)
# Saving to: ‘S07E.mat’
#
# S07E.mat            100%[===================>]  22.89M  6.48MB/s    in 3.5s
#
# 2018-06-16 01:42:24 (6.48 MB/s) - ‘S07E.mat’ saved [23997847/23997847]
#
# --2018-06-16 01:42:25--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S08T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S08T.mat [following]
# --2018-06-16 01:42:25--  https://lampx.tugraz.at/~bci/database/002-2014/S08T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39735612 (38M)
# Saving to: ‘S08T.mat’
#
# S08T.mat              5%[>                   ]   2.21M   951KB/s
# S08T.mat            100%[===================>]  37.89M  9.48MB/s    in 4.5s
#
# 2018-06-16 01:42:30 (8.48 MB/s) - ‘S08T.mat’ saved [39735612/39735612]
#
# --2018-06-16 01:42:31--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S08E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S08E.mat [following]
# --2018-06-16 01:42:31--  https://lampx.tugraz.at/~bci/database/002-2014/S08E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23791571 (23M)
# Saving to: ‘S08E.mat’
#
# S08E.mat            100%[===================>]  22.69M  6.34MB/s    in 3.6s
#
# 2018-06-16 01:42:35 (6.34 MB/s) - ‘S08E.mat’ saved [23791571/23791571]
#
# --2018-06-16 01:42:36--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S09T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S09T.mat [following]
# --2018-06-16 01:42:37--  https://lampx.tugraz.at/~bci/database/002-2014/S09T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39805150 (38M)
# Saving to: ‘S09T.mat’
#
# S09T.mat            100%[===================>]  37.96M  9.49MB/s    in 4.7s
#
# 2018-06-16 01:42:42 (8.07 MB/s) - ‘S09T.mat’ saved [39805150/39805150]
#
# --2018-06-16 01:42:43--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S09E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S09E.mat [following]
# --2018-06-16 01:42:43--  https://lampx.tugraz.at/~bci/database/002-2014/S09E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23610622 (23M)
# Saving to: ‘S09E.mat’
#
# S09E.mat              3%[                    ] 712.00K   426KB/s
# S09E.mat            100%[===================>]  22.52M  5.90MB/s    in 3.8s
#
# 2018-06-16 01:42:48 (5.90 MB/s) - ‘S09E.mat’ saved [23610622/23610622]
#
# --2018-06-16 01:42:49--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S10T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S10T.mat [following]
# --2018-06-16 01:42:49--  https://lampx.tugraz.at/~bci/database/002-2014/S10T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39871971 (38M)
# Saving to: ‘S10T.mat’
#
# S10T.mat            100%[===================>]  38.02M  9.19MB/s    in 4.6s
#
# 2018-06-16 01:42:54 (8.25 MB/s) - ‘S10T.mat’ saved [39871971/39871971]
#
# --2018-06-16 01:42:55--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S10E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S10E.mat [following]
# --2018-06-16 01:42:55--  https://lampx.tugraz.at/~bci/database/002-2014/S10E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23750112 (23M)
# Saving to: ‘S10E.mat’
#
# S10E.mat            100%[===================>]  22.65M  6.40MB/s    in 3.5s
#
# 2018-06-16 01:42:59 (6.40 MB/s) - ‘S10E.mat’ saved [23750112/23750112]
#
# --2018-06-16 01:43:01--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S11T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S11T.mat [following]
# --2018-06-16 01:43:01--  https://lampx.tugraz.at/~bci/database/002-2014/S11T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40140184 (38M)
# Saving to: ‘S11T.mat’
#
# S11T.mat              4%[                    ]   1.63M   701KB/s
# S11T.mat            100%[===================>]  38.28M  9.52MB/s    in 4.7s
#
# 2018-06-16 01:43:06 (8.10 MB/s) - ‘S11T.mat’ saved [40140184/40140184]
#
# --2018-06-16 01:43:07--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S11E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S11E.mat [following]
# --2018-06-16 01:43:08--  https://lampx.tugraz.at/~bci/database/002-2014/S11E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24171700 (23M)
# Saving to: ‘S11E.mat’
#
# S11E.mat            100%[===================>]  23.05M  6.23MB/s    in 3.7s
#
# 2018-06-16 01:43:12 (6.23 MB/s) - ‘S11E.mat’ saved [24171700/24171700]
#
# --2018-06-16 01:43:13--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S12T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S12T.mat [following]
# --2018-06-16 01:43:13--  https://lampx.tugraz.at/~bci/database/002-2014/S12T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40093093 (38M)
# Saving to: ‘S12T.mat’
#
# S12T.mat            100%[===================>]  38.24M  9.30MB/s    in 4.3s
#
# 2018-06-16 01:43:18 (8.80 MB/s) - ‘S12T.mat’ saved [40093093/40093093]
#
# --2018-06-16 01:43:19--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S12E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S12E.mat [following]
# --2018-06-16 01:43:19--  https://lampx.tugraz.at/~bci/database/002-2014/S12E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23905075 (23M)
# Saving to: ‘S12E.mat’
#
# S12E.mat              4%[                    ]   1016K   534KB/s
# S12E.mat            100%[===================>]  22.80M  6.11MB/s    in 3.7s
#
# 2018-06-16 01:43:24 (6.11 MB/s) - ‘S12E.mat’ saved [23905075/23905075]
#
# --2018-06-16 01:43:25--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S13T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S13T.mat [following]
# --2018-06-16 01:43:25--  https://lampx.tugraz.at/~bci/database/002-2014/S13T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39819174 (38M)
# Saving to: ‘S13T.mat’
#
# S13T.mat            100%[===================>]  37.97M  9.69MB/s    in 4.4s
#
# 2018-06-16 01:43:30 (8.65 MB/s) - ‘S13T.mat’ saved [39819174/39819174]
#
# --2018-06-16 01:43:31--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S13E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S13E.mat [following]
# --2018-06-16 01:43:31--  https://lampx.tugraz.at/~bci/database/002-2014/S13E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23669359 (23M)
# Saving to: ‘S13E.mat’
#
# S13E.mat            100%[===================>]  22.57M  6.22MB/s    in 3.6s
#
# 2018-06-16 01:43:36 (6.22 MB/s) - ‘S13E.mat’ saved [23669359/23669359]
#
# --2018-06-16 01:43:37--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S14T.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S14T.mat [following]
# --2018-06-16 01:43:37--  https://lampx.tugraz.at/~bci/database/002-2014/S14T.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39859134 (38M)
# Saving to: ‘S14T.mat’
#
# S14T.mat              4%[                    ]   1.85M   880KB/s
# S14T.mat            100%[===================>]  38.01M  9.37MB/s    in 4.3s
#
# 2018-06-16 01:43:42 (8.85 MB/s) - ‘S14T.mat’ saved [39859134/39859134]
#
# --2018-06-16 01:43:43--  http://bnci-horizon-2020.eu/database/data-sets/002-2014/S14E.mat
# Resolving bnci-horizon-2020.eu (bnci-horizon-2020.eu)... 91.227.204.35
# Connecting to bnci-horizon-2020.eu (bnci-horizon-2020.eu)|91.227.204.35|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lampx.tugraz.at/~bci/database/002-2014/S14E.mat [following]
# --2018-06-16 01:43:43--  https://lampx.tugraz.at/~bci/database/002-2014/S14E.mat
# Resolving lampx.tugraz.at (lampx.tugraz.at)... 129.27.124.207
# Connecting to lampx.tugraz.at (lampx.tugraz.at)|129.27.124.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23970887 (23M)
# Saving to: ‘S14E.mat’
#
# S14E.mat            100%[===================>]  22.86M  6.09MB/s    in 3.8s
#
# 2018-06-16 01:43:47 (6.09 MB/s) - ‘S14E.mat’ saved [23970887/23970887]
#
#
# (2240, 15, 3584)
# (2240,)

# %%
# load the general network Trainer
from brainDecodeSKLearnWrapper.ShallowFBCSPNet_GeneralTrainer import ShallowFBCSPNet_GeneralTrainer

classifier = ShallowFBCSPNet_GeneralTrainer()
classifier.fit(X,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:67: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Epoch 0
# Train  Loss: 0.96520
# Train  Accuracy: 48.1%
# Test   Loss: 0.87153
# Test   Accuracy: 55.4%
# Epoch 1
# Train  Loss: 1.00303
# Train  Accuracy: 48.6%
# Test   Loss: 0.91248
# Test   Accuracy: 56.4%
# Epoch 2
# Train  Loss: 0.72225
# Train  Accuracy: 55.4%
# Test   Loss: 0.74053
# Test   Accuracy: 50.7%
# Epoch 3
# Train  Loss: 0.70537
# Train  Accuracy: 55.3%
# Test   Loss: 0.73199
# Test   Accuracy: 52.9%
# Epoch 4
# Train  Loss: 0.69171
# Train  Accuracy: 55.0%
# Test   Loss: 0.72662
# Test   Accuracy: 48.9%
# Epoch 5
# Train  Loss: 0.72288
# Train  Accuracy: 53.0%
# Test   Loss: 0.73340
# Test   Accuracy: 53.6%
# Epoch 6
# Train  Loss: 0.78398
# Train  Accuracy: 51.5%
# Test   Loss: 0.86019
# Test   Accuracy: 47.1%
# Epoch 7
# Train  Loss: 0.71520
# Train  Accuracy: 53.4%
# Test   Loss: 0.72639
# Test   Accuracy: 52.5%
# Epoch 8
# Train  Loss: 0.69865
# Train  Accuracy: 57.3%
# Test   Loss: 0.72801
# Test   Accuracy: 53.2%
# Epoch 9
# Train  Loss: 1.28257
# Train  Accuracy: 50.5%
# Test   Loss: 1.42833
# Test   Accuracy: 45.7%
# Epoch 10
# Train  Loss: 0.62912
# Train  Accuracy: 65.5%
# Test   Loss: 0.66617
# Test   Accuracy: 55.7%
# Epoch 11
# Train  Loss: 0.61808
# Train  Accuracy: 66.4%
# Test   Loss: 0.66469
# Test   Accuracy: 58.2%
# Epoch 12
# Train  Loss: 0.60280
# Train  Accuracy: 68.5%
# Test   Loss: 0.65019
# Test   Accuracy: 61.1%
# Epoch 13
# Train  Loss: 0.58679
# Train  Accuracy: 68.5%
# Test   Loss: 0.62692
# Test   Accuracy: 61.4%
# Epoch 14
# Train  Loss: 0.58665
# Train  Accuracy: 68.0%
# Test   Loss: 0.61181
# Test   Accuracy: 65.0%
# Epoch 15
# Train  Loss: 0.56506
# Train  Accuracy: 71.6%
# Test   Loss: 0.60440
# Test   Accuracy: 62.9%
# Epoch 16
# Train  Loss: 0.75442
# Train  Accuracy: 54.9%
# Test   Loss: 0.73154
# Test   Accuracy: 58.9%
# Epoch 17
# Train  Loss: 0.93976
# Train  Accuracy: 53.2%
# Test   Loss: 0.89259
# Test   Accuracy: 56.4%
# Epoch 18
# Train  Loss: 0.55042
# Train  Accuracy: 71.5%
# Test   Loss: 0.58451
# Test   Accuracy: 65.7%
# Epoch 19
# Train  Loss: 0.52000
# Train  Accuracy: 73.9%
# Test   Loss: 0.58131
# Test   Accuracy: 66.4%
# Epoch 20
# Train  Loss: 0.50811
# Train  Accuracy: 74.9%
# Test   Loss: 0.57463
# Test   Accuracy: 70.0%
# Epoch 21
# Train  Loss: 2.24763
# Train  Accuracy: 49.7%
# Test   Loss: 2.08964
# Test   Accuracy: 55.0%
# Epoch 22
# Train  Loss: 0.51093
# Train  Accuracy: 73.2%
# Test   Loss: 0.54563
# Test   Accuracy: 72.9%
# Epoch 23
# Train  Loss: 0.49552
# Train  Accuracy: 75.9%
# Test   Loss: 0.53663
# Test   Accuracy: 70.4%
# Epoch 24
# Train  Loss: 0.59373
# Train  Accuracy: 65.8%
# Test   Loss: 0.60556
# Test   Accuracy: 66.8%
# Epoch 25
# Train  Loss: 0.48142
# Train  Accuracy: 77.4%
# Test   Loss: 0.54240
# Test   Accuracy: 68.9%
# Epoch 26
# Train  Loss: 0.50683
# Train  Accuracy: 75.2%
# Test   Loss: 0.55791
# Test   Accuracy: 71.1%
# Epoch 27
# Train  Loss: 0.47060
# Train  Accuracy: 78.0%
# Test   Loss: 0.52443
# Test   Accuracy: 71.4%
# Epoch 28
# Train  Loss: 0.52321
# Train  Accuracy: 71.8%
# Test   Loss: 0.56968
# Test   Accuracy: 67.5%
# Epoch 29
# Train  Loss: 0.46835
# Train  Accuracy: 78.0%
# Test   Loss: 0.54278
# Test   Accuracy: 69.6%
# Epoch 30
# Train  Loss: 0.53597
# Train  Accuracy: 69.6%
# Test   Loss: 0.58371
# Test   Accuracy: 69.3%
# Epoch 31
# Train  Loss: 0.49244
# Train  Accuracy: 73.2%
# Test   Loss: 0.53744
# Test   Accuracy: 71.8%
# Epoch 32
# Train  Loss: 0.59916
# Train  Accuracy: 66.2%
# Test   Loss: 0.61190
# Test   Accuracy: 66.4%
# Epoch 33
# Train  Loss: 0.68292
# Train  Accuracy: 60.3%
# Test   Loss: 0.71491
# Test   Accuracy: 63.9%
# Epoch 34
# Train  Loss: 0.44035
# Train  Accuracy: 80.5%
# Test   Loss: 0.51628
# Test   Accuracy: 71.4%
# Epoch 35
# Train  Loss: 0.54559
# Train  Accuracy: 70.0%
# Test   Loss: 0.59993
# Test   Accuracy: 68.9%
# Epoch 36
# Train  Loss: 0.45137
# Train  Accuracy: 80.2%
# Test   Loss: 0.53663
# Test   Accuracy: 71.4%
# Epoch 37
# Train  Loss: 0.48272
# Train  Accuracy: 75.0%
# Test   Loss: 0.56258
# Test   Accuracy: 72.1%
# Epoch 38
# Train  Loss: 0.47355
# Train  Accuracy: 75.3%
# Test   Loss: 0.54563
# Test   Accuracy: 70.7%
# Epoch 39
# Train  Loss: 1.26676
# Train  Accuracy: 53.1%
# Test   Loss: 1.26652
# Test   Accuracy: 56.8%
# Epoch 40
# Train  Loss: 0.43430
# Train  Accuracy: 79.4%
# Test   Loss: 0.51697
# Test   Accuracy: 72.5%
# Epoch 41
# Train  Loss: 0.42779
# Train  Accuracy: 80.8%
# Test   Loss: 0.50886
# Test   Accuracy: 73.2%
# Epoch 42
# Train  Loss: 0.66922
# Train  Accuracy: 63.0%
# Test   Loss: 0.71695
# Test   Accuracy: 64.3%
# Epoch 43
# Train  Loss: 1.27709
# Train  Accuracy: 53.3%
# Test   Loss: 1.27170
# Test   Accuracy: 57.5%
# Epoch 44
# Train  Loss: 0.42205
# Train  Accuracy: 80.4%
# Test   Loss: 0.51197
# Test   Accuracy: 73.2%
# Epoch 45
# Train  Loss: 0.41448
# Train  Accuracy: 81.4%
# Test   Loss: 0.49816
# Test   Accuracy: 73.6%
# Epoch 46
# Train  Loss: 0.48472
# Train  Accuracy: 75.2%
# Test   Loss: 0.55534
# Test   Accuracy: 72.1%
# Epoch 47
# Train  Loss: 0.45711
# Train  Accuracy: 77.0%
# Test   Loss: 0.52840
# Test   Accuracy: 71.4%
# Epoch 48
# Train  Loss: 0.41393
# Train  Accuracy: 81.2%
# Test   Loss: 0.50685
# Test   Accuracy: 72.1%
# Epoch 49
# Train  Loss: 0.40989
# Train  Accuracy: 82.7%
# Test   Loss: 0.48840
# Test   Accuracy: 72.1%
# Epoch 50
# Train  Loss: 0.40126
# Train  Accuracy: 82.7%
# Test   Loss: 0.48898
# Test   Accuracy: 72.9%
# Epoch 51
# Train  Loss: 0.41801
# Train  Accuracy: 81.9%
# Test   Loss: 0.48593
# Test   Accuracy: 73.6%
# Epoch 52
# Train  Loss: 0.71954
# Train  Accuracy: 61.0%
# Test   Loss: 0.76337
# Test   Accuracy: 64.3%
# Epoch 53
# Train  Loss: 0.39952
# Train  Accuracy: 82.4%
# Test   Loss: 0.48915
# Test   Accuracy: 74.3%
# Epoch 54
# Train  Loss: 0.70721
# Train  Accuracy: 61.2%
# Test   Loss: 0.73822
# Test   Accuracy: 64.3%
# Epoch 55
# Train  Loss: 0.41503
# Train  Accuracy: 81.3%
# Test   Loss: 0.50772
# Test   Accuracy: 75.4%
# Epoch 56
# Train  Loss: 0.40197
# Train  Accuracy: 81.3%
# Test   Loss: 0.51204
# Test   Accuracy: 72.5%
# Epoch 57
# Train  Loss: 0.40577
# Train  Accuracy: 81.1%
# Test   Loss: 0.50066
# Test   Accuracy: 73.9%
# Epoch 58
# Train  Loss: 0.46597
# Train  Accuracy: 74.9%
# Test   Loss: 0.55663
# Test   Accuracy: 71.1%
# Epoch 59
# Train  Loss: 0.42981
# Train  Accuracy: 79.3%
# Test   Loss: 0.51207
# Test   Accuracy: 71.1%
# Epoch 60
# Train  Loss: 0.39440
# Train  Accuracy: 82.2%
# Test   Loss: 0.48359
# Test   Accuracy: 74.3%
# Epoch 61
# Train  Loss: 0.54392
# Train  Accuracy: 69.1%
# Test   Loss: 0.59720
# Test   Accuracy: 70.7%
# Epoch 62
# Train  Loss: 0.52487
# Train  Accuracy: 70.1%
# Test   Loss: 0.57553
# Test   Accuracy: 71.1%
# Epoch 63
# Train  Loss: 0.63274
# Train  Accuracy: 66.2%
# Test   Loss: 0.70183
# Test   Accuracy: 65.4%
# Epoch 64
# Train  Loss: 0.51234
# Train  Accuracy: 72.4%
# Test   Loss: 0.62003
# Test   Accuracy: 67.9%
# Epoch 65
# Train  Loss: 0.73421
# Train  Accuracy: 62.1%
# Test   Loss: 0.78431
# Test   Accuracy: 62.9%
# Epoch 66
# Train  Loss: 0.40095
# Train  Accuracy: 82.5%
# Test   Loss: 0.47589
# Test   Accuracy: 73.9%
# Epoch 67
# Train  Loss: 0.52046
# Train  Accuracy: 72.1%
# Test   Loss: 0.60212
# Test   Accuracy: 67.9%
# Epoch 68
# Train  Loss: 0.38521
# Train  Accuracy: 83.2%
# Test   Loss: 0.48385
# Test   Accuracy: 75.4%
# Epoch 69
# Train  Loss: 0.37042
# Train  Accuracy: 84.7%
# Test   Loss: 0.46098
# Test   Accuracy: 76.4%
# Epoch 70
# Train  Loss: 0.43591
# Train  Accuracy: 78.2%
# Test   Loss: 0.56555
# Test   Accuracy: 69.6%
# Epoch 71
# Train  Loss: 0.37889
# Train  Accuracy: 83.7%
# Test   Loss: 0.46378
# Test   Accuracy: 75.7%
# Epoch 72
# Train  Loss: 0.36435
# Train  Accuracy: 84.7%
# Test   Loss: 0.45732
# Test   Accuracy: 75.4%
# Epoch 73
# Train  Loss: 0.40326
# Train  Accuracy: 80.4%
# Test   Loss: 0.49092
# Test   Accuracy: 75.7%
# Epoch 74
# Train  Loss: 0.37117
# Train  Accuracy: 83.9%
# Test   Loss: 0.48008
# Test   Accuracy: 75.0%
# Epoch 75
# Train  Loss: 0.37747
# Train  Accuracy: 83.6%
# Test   Loss: 0.49086
# Test   Accuracy: 76.4%
# Epoch 76
# Train  Loss: 0.35992
# Train  Accuracy: 84.6%
# Test   Loss: 0.47897
# Test   Accuracy: 76.4%
# Epoch 77
# Train  Loss: 0.36624
# Train  Accuracy: 84.2%
# Test   Loss: 0.49909
# Test   Accuracy: 74.6%
# Epoch 78
# Train  Loss: 0.64854
# Train  Accuracy: 64.9%
# Test   Loss: 0.69265
# Test   Accuracy: 66.1%
# Epoch 79
# Train  Loss: 0.60970
# Train  Accuracy: 66.0%
# Test   Loss: 0.66839
# Test   Accuracy: 65.7%
# Epoch 80
# Train  Loss: 0.36651
# Train  Accuracy: 84.4%
# Test   Loss: 0.46248
# Test   Accuracy: 78.2%
# Epoch 81
# Train  Loss: 0.37817
# Train  Accuracy: 83.2%
# Test   Loss: 0.51270
# Test   Accuracy: 74.3%
# Epoch 82
# Train  Loss: 0.38784
# Train  Accuracy: 81.8%
# Test   Loss: 0.50440
# Test   Accuracy: 76.4%
# Epoch 83
# Train  Loss: 0.36526
# Train  Accuracy: 85.5%
# Test   Loss: 0.47871
# Test   Accuracy: 75.7%
# Epoch 84
# Train  Loss: 0.59360
# Train  Accuracy: 68.8%
# Test   Loss: 0.63026
# Test   Accuracy: 68.6%
# Epoch 85
# Train  Loss: 0.73264
# Train  Accuracy: 61.5%
# Test   Loss: 0.77750
# Test   Accuracy: 63.2%
# Epoch 86
# Train  Loss: 0.45904
# Train  Accuracy: 74.9%
# Test   Loss: 0.54469
# Test   Accuracy: 71.8%
# Epoch 87
# Train  Loss: 0.40304
# Train  Accuracy: 80.5%
# Test   Loss: 0.50436
# Test   Accuracy: 72.5%
# Epoch 88
# Train  Loss: 0.35443
# Train  Accuracy: 85.4%
# Test   Loss: 0.47672
# Test   Accuracy: 74.6%
# Epoch 89
# Train  Loss: 0.37089
# Train  Accuracy: 84.3%
# Test   Loss: 0.51482
# Test   Accuracy: 75.7%
# Epoch 90
# Train  Loss: 0.47332
# Train  Accuracy: 73.8%
# Test   Loss: 0.57785
# Test   Accuracy: 70.0%
# Epoch 91
# Train  Loss: 0.33543
# Train  Accuracy: 86.7%
# Test   Loss: 0.46536
# Test   Accuracy: 77.9%
# Epoch 92
# Train  Loss: 0.34426
# Train  Accuracy: 86.3%
# Test   Loss: 0.45306
# Test   Accuracy: 77.5%
# Epoch 93
# Train  Loss: 0.32958
# Train  Accuracy: 87.8%
# Test   Loss: 0.46160
# Test   Accuracy: 74.6%
# Epoch 94
# Train  Loss: 0.58135
# Train  Accuracy: 69.3%
# Test   Loss: 0.68678
# Test   Accuracy: 65.7%
# Epoch 95
# Train  Loss: 0.68301
# Train  Accuracy: 65.0%
# Test   Loss: 0.75994
# Test   Accuracy: 64.3%
# Epoch 96
# Train  Loss: 0.33377
# Train  Accuracy: 86.7%
# Test   Loss: 0.47036
# Test   Accuracy: 75.4%
# Epoch 97
# Train  Loss: 0.46763
# Train  Accuracy: 77.6%
# Test   Loss: 0.53869
# Test   Accuracy: 75.0%
# Epoch 98
# Train  Loss: 0.50159
# Train  Accuracy: 71.7%
# Test   Loss: 0.62868
# Test   Accuracy: 67.1%
# Epoch 99
# Train  Loss: 0.38434
# Train  Accuracy: 82.4%
# Test   Loss: 0.49387
# Test   Accuracy: 75.4%
# Epoch 100
# Train  Loss: 0.37618
# Train  Accuracy: 82.8%
# Test   Loss: 0.46827
# Test   Accuracy: 75.4%
# Epoch 101
# Train  Loss: 0.33765
# Train  Accuracy: 86.9%
# Test   Loss: 0.44799
# Test   Accuracy: 77.9%
# Epoch 102
# Train  Loss: 0.40315
# Train  Accuracy: 79.9%
# Test   Loss: 0.52444
# Test   Accuracy: 73.6%
# Epoch 103
# Train  Loss: 0.77058
# Train  Accuracy: 61.3%
# Test   Loss: 0.84855
# Test   Accuracy: 62.5%
# Epoch 104
# Train  Loss: 0.68528
# Train  Accuracy: 63.8%
# Test   Loss: 0.77914
# Test   Accuracy: 63.6%
# Epoch 105
# Train  Loss: 0.48181
# Train  Accuracy: 74.7%
# Test   Loss: 0.59006
# Test   Accuracy: 72.5%
# Epoch 106
# Train  Loss: 0.56301
# Train  Accuracy: 69.5%
# Test   Loss: 0.69681
# Test   Accuracy: 64.6%
# Epoch 107
# Train  Loss: 0.42249
# Train  Accuracy: 77.5%
# Test   Loss: 0.55157
# Test   Accuracy: 74.3%
# Epoch 108
# Train  Loss: 0.56922
# Train  Accuracy: 69.4%
# Test   Loss: 0.69148
# Test   Accuracy: 67.5%
# Epoch 109
# Train  Loss: 0.32631
# Train  Accuracy: 87.0%
# Test   Loss: 0.45602
# Test   Accuracy: 77.5%
# Epoch 110
# Train  Loss: 0.49056
# Train  Accuracy: 72.9%
# Test   Loss: 0.61035
# Test   Accuracy: 68.9%
# Epoch 111
# Train  Loss: 0.33433
# Train  Accuracy: 86.9%
# Test   Loss: 0.48435
# Test   Accuracy: 74.3%
# Epoch 112
# Train  Loss: 0.34457
# Train  Accuracy: 84.4%
# Test   Loss: 0.52446
# Test   Accuracy: 76.4%
# Epoch 113
# Train  Loss: 0.36230
# Train  Accuracy: 84.3%
# Test   Loss: 0.50524
# Test   Accuracy: 76.1%
# Epoch 114
# Train  Loss: 0.31502
# Train  Accuracy: 88.0%
# Test   Loss: 0.45761
# Test   Accuracy: 75.4%
# Epoch 115
# Train  Loss: 0.41509
# Train  Accuracy: 78.2%
# Test   Loss: 0.57444
# Test   Accuracy: 69.3%
# Epoch 116
# Train  Loss: 0.61166
# Train  Accuracy: 66.2%
# Test   Loss: 0.73319
# Test   Accuracy: 66.1%
# Epoch 117
# Train  Loss: 0.32926
# Train  Accuracy: 85.5%
# Test   Loss: 0.52816
# Test   Accuracy: 73.9%
# Epoch 118
# Train  Loss: 0.33399
# Train  Accuracy: 86.7%
# Test   Loss: 0.48019
# Test   Accuracy: 74.6%
# Epoch 119
# Train  Loss: 0.31902
# Train  Accuracy: 87.7%
# Test   Loss: 0.48019
# Test   Accuracy: 75.4%
# Epoch 120
# Train  Loss: 0.30161
# Train  Accuracy: 88.7%
# Test   Loss: 0.47639
# Test   Accuracy: 74.6%
# Epoch 121
# Train  Loss: 0.61348
# Train  Accuracy: 66.3%
# Test   Loss: 0.76881
# Test   Accuracy: 66.1%
# Epoch 122
# Train  Loss: 0.74330
# Train  Accuracy: 62.9%
# Test   Loss: 0.87213
# Test   Accuracy: 63.6%
# Epoch 123
# Train  Loss: 0.31006
# Train  Accuracy: 88.3%
# Test   Loss: 0.47424
# Test   Accuracy: 76.4%
# Epoch 124
# Train  Loss: 0.29583
# Train  Accuracy: 88.7%
# Test   Loss: 0.47192
# Test   Accuracy: 77.1%
# Epoch 125
# Train  Loss: 0.31034
# Train  Accuracy: 88.0%
# Test   Loss: 0.45847
# Test   Accuracy: 76.4%
# Epoch 126
# Train  Loss: 0.32756
# Train  Accuracy: 87.4%
# Test   Loss: 0.46806
# Test   Accuracy: 75.0%
# Epoch 127
# Train  Loss: 0.31769
# Train  Accuracy: 87.1%
# Test   Loss: 0.49386
# Test   Accuracy: 75.7%
# Epoch 128
# Train  Loss: 0.30330
# Train  Accuracy: 89.1%
# Test   Loss: 0.44533
# Test   Accuracy: 77.9%
# Epoch 129
# Train  Loss: 0.31116
# Train  Accuracy: 88.2%
# Test   Loss: 0.48268
# Test   Accuracy: 75.4%
# Epoch 130
# Train  Loss: 0.30884
# Train  Accuracy: 88.0%
# Test   Loss: 0.45188
# Test   Accuracy: 75.7%
# Epoch 131
# Train  Loss: 0.31765
# Train  Accuracy: 85.9%
# Test   Loss: 0.50170
# Test   Accuracy: 75.0%
# Epoch 132
# Train  Loss: 0.32732
# Train  Accuracy: 85.8%
# Test   Loss: 0.49140
# Test   Accuracy: 76.4%
# Epoch 133
# Train  Loss: 0.29584
# Train  Accuracy: 87.7%
# Test   Loss: 0.49519
# Test   Accuracy: 73.6%
# Epoch 134
# Train  Loss: 0.36212
# Train  Accuracy: 82.4%
# Test   Loss: 0.51922
# Test   Accuracy: 76.4%
# Epoch 135
# Train  Loss: 0.36532
# Train  Accuracy: 83.5%
# Test   Loss: 0.50801
# Test   Accuracy: 74.6%
# Epoch 136
# Train  Loss: 0.29607
# Train  Accuracy: 89.3%
# Test   Loss: 0.46769
# Test   Accuracy: 75.7%
# Epoch 137
# Train  Loss: 0.48818
# Train  Accuracy: 72.8%
# Test   Loss: 0.63825
# Test   Accuracy: 67.1%
# Epoch 138
# Train  Loss: 0.68799
# Train  Accuracy: 63.2%
# Test   Loss: 0.79781
# Test   Accuracy: 63.6%
# Epoch 139
# Train  Loss: 0.29895
# Train  Accuracy: 89.5%
# Test   Loss: 0.46309
# Test   Accuracy: 76.4%
# Epoch 140
# Train  Loss: 0.29930
# Train  Accuracy: 88.6%
# Test   Loss: 0.47378
# Test   Accuracy: 77.5%
# Epoch 141
# Train  Loss: 0.40457
# Train  Accuracy: 79.9%
# Test   Loss: 0.55970
# Test   Accuracy: 72.9%
# Epoch 142
# Train  Loss: 0.29469
# Train  Accuracy: 89.0%
# Test   Loss: 0.46789
# Test   Accuracy: 77.1%
# Epoch 143
# Train  Loss: 0.65110
# Train  Accuracy: 65.5%
# Test   Loss: 0.78711
# Test   Accuracy: 63.9%
# Epoch 144
# Train  Loss: 0.37019
# Train  Accuracy: 84.1%
# Test   Loss: 0.53321
# Test   Accuracy: 76.8%
# Epoch 145
# Train  Loss: 0.52668
# Train  Accuracy: 70.6%
# Test   Loss: 0.66008
# Test   Accuracy: 67.5%
# Epoch 146
# Train  Loss: 0.47062
# Train  Accuracy: 76.9%
# Test   Loss: 0.56392
# Test   Accuracy: 75.4%
# Epoch 147
# Train  Loss: 0.43196
# Train  Accuracy: 76.9%
# Test   Loss: 0.61369
# Test   Accuracy: 69.6%
# Epoch 148
# Train  Loss: 0.31040
# Train  Accuracy: 87.9%
# Test   Loss: 0.53266
# Test   Accuracy: 74.3%
# Epoch 149
# Train  Loss: 0.29486
# Train  Accuracy: 88.8%
# Test   Loss: 0.47460
# Test   Accuracy: 77.5%
# Epoch 150
# Train  Loss: 0.63702
# Train  Accuracy: 66.7%
# Test   Loss: 0.75825
# Test   Accuracy: 65.4%
# Epoch 151
# Train  Loss: 0.73227
# Train  Accuracy: 62.9%
# Test   Loss: 0.90194
# Test   Accuracy: 61.1%
# Epoch 152
# Train  Loss: 0.79744
# Train  Accuracy: 61.9%
# Test   Loss: 0.89384
# Test   Accuracy: 62.1%
# Epoch 153
# Train  Loss: 0.27882
# Train  Accuracy: 89.2%
# Test   Loss: 0.47388
# Test   Accuracy: 78.6%
# Epoch 154
# Train  Loss: 0.63025
# Train  Accuracy: 69.1%
# Test   Loss: 0.74161
# Test   Accuracy: 66.4%
# Epoch 155
# Train  Loss: 0.31951
# Train  Accuracy: 85.9%
# Test   Loss: 0.51444
# Test   Accuracy: 76.1%
# Epoch 156
# Train  Loss: 0.27573
# Train  Accuracy: 89.4%
# Test   Loss: 0.51197
# Test   Accuracy: 77.1%
# Epoch 157
# Train  Loss: 0.28272
# Train  Accuracy: 89.2%
# Test   Loss: 0.48360
# Test   Accuracy: 73.6%
# Epoch 158
# Train  Loss: 0.37439
# Train  Accuracy: 82.4%
# Test   Loss: 0.57646
# Test   Accuracy: 73.9%
# Epoch 159
# Train  Loss: 0.30443
# Train  Accuracy: 89.1%
# Test   Loss: 0.49829
# Test   Accuracy: 75.4%
# ShallowFBCSPNet_GeneralTrainer(filter_time_length=75, n_filters_spat=5,
#                 n_filters_time=10, nb_epoch=160, pool_time_length=60,
#                 pool_time_stride=30)

# %%
from brainDecodeSKLearnWrapper.ShallowFBCSPNet_SpecializedTrainer import ShallowFBCSPNet_SpecializedTrainer





"""
Now, let's load data.

We read the file for the desired subject, and parse the data to extract:
- samplingRate
- trialLength
- X, a M x N x K matrix, which stands for trial x chan x samples
    - the actual values are 160 x 15 x 2560
- y, a M vector containing the labels {0,1}

ref: Dataset description: https://lampx.tugraz.at/~bci/database/002-2014/description.pdf
"""

folder = "BBCIData"
datasetID = 1

# prepare data containers
y = []
X = []

f = listdir(folder)[datasetID]
  
# read file
d1T = sio.loadmat(folder + "/" + f)

samplingRate = d1T['data'][0][0][0][0][3][0][0]
trialLength = 7*samplingRate

# run through all training runs
for run in range(len(d1T['data'][0])):
    y.append(d1T['data'][0][run][0][0][2][0]) # labels
    timestamps = d1T['data'][0][run][0][0][1][0] # timestamps
    rawData = d1T['data'][0][run][0][0][0].transpose() # chan x data

    # parse out data based on timestamps
    for start in timestamps:
        end = start + trialLength
        X.append(rawData[:,start:end]) #15 x 2560

del rawData
del d1T

# arrange data into num7py arrays
# also torch expect float32 for samples
# and int64 for labels {0,1}
X = np.array(X).astype(np.float32)
y = (np.array(y).flatten()-1).astype(np.int64)
print()
print(X.shape)
print(y.shape)


# rand permute dataset
idx = np.random.permutation(X.shape[0])

X = X[idx,:,:]
y = y[idx]







specializedClassifier = ShallowFBCSPNet_SpecializedTrainer(network=classifier.model)
specializedClassifier.lr = 0.01
#specializedClassifier.configure(initial_lr=0.01)
specializedClassifier.fit(X,y)
# Out:
#   File "/content/dl-eeg-playground/brainDecode/towardMoabbIntegration/brainDecodeSKLearnWrapper/ShallowFBCSPNet_SpecializedTrainer.py", line 41
#     trainTestRatio=7/8):
#                  ^
# SyntaxError: invalid syntax

# %%
specializedClassifier = ShallowFBCSPNet_SpecializedTrainer(filename="myModel.pth")
specializedClassifier.lr = 0.01
#specializedClassifier.configure(initial_lr=0.01)
specializedClassifier.fit(X,y)

# %% [markdown]
# Best scores so far:
#
# Subject 0: 76.9%
# Subject 1 50.0%
